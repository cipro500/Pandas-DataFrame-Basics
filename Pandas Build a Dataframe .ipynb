# %%
import pandas as pd

# %%
#Constructing a dataframe
employee_df= pd.DataFrame({"Employee ID":[1,2,3,4], 
                           "Employee Name":['Laila Aly','Kate Steve','Francis Morris','Nicole Mitch'],
                            'Annual Salary':[35000,40000,100000,25000],
                           "Years with company":[5,7,10,1]})

# %%
# describes data type
type(employee_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#first 5 in dataframe
employee_df.head()
# Out:
#    Employee ID   Employee Name  Annual Salary  Years with company
# 0            1       Laila Aly          35000                   5
# 1            2      Kate Steve          40000                   7
# 2            3  Francis Morris         100000                  10
# 3            4    Nicole Mitch          25000                   1

# %%
#last 2 in dataframe 
employee_df.tail(2)
# Out:
#    Employee ID   Employee Name  Annual Salary  Years with company
# 2            3  Francis Morris         100000                  10
# 3            4    Nicole Mitch          25000                   1

# %%
#shape of dataframe
employee_df.shape
# Out:
# (4, 4)

# %%
# obtain data information about dataframe
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# Employee ID           4 non-null int64
# Employee Name         4 non-null object
# Annual Salary         4 non-null int64
# Years with company    4 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 208.0+ bytes

# %%
#total compensation
total_company_compensation= employee_df['Annual Salary']*employee_df['Years with company']
total_company_compensation
# Out:
# 0     175000
# 1     280000
# 2    1000000
# 3      25000
# dtype: int64

# %%
total_company_compensation.sum()
# Out:
# 1480000

# %%
#read csv file into dataframe
employee_df= pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#read html website into dataframe
house_prices_df=pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')
house_prices_df
# Out:
# [                                                City  \
#  0                                      Vancouver, BC
#  1                                       Toronto, Ont
#  2                                        Ottawa, Ont
#  3                                       Calgary, Alb
#  4                                      Montreal, Que
#  5                                        Halifax, NS
#  6                                       Regina, Sask
#  7                                    Fredericton, NB
#  8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
#  0                                         $1,036,000
#  1                                           $870,000
#  2                                           $479,000
#  3                                           $410,000
#  4                                           $435,000
#  5                                           $331,000
# ...

# %%
#grab first table
house_prices_df[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# ...

# %%
#grab second table
house_prices_df[1]
# Out:
#                                              Province  \
# 0                                    British Columbia
# 1                                             Ontario
# 2                                             Alberta
# 3                                              Quebec
# 4                                            Manitoba
# 5                                        Saskatchewan
# 6                                         Nova Scotia
# 7                                Prince Edward Island
# 8                             Newfoundland / Labrador
# 9                                       New Brunswick
# 10                                   Canadian Average
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
# 0                                            $736,000
# 1                                            $594,000
# 2                                            $353,000
# ...

# %%
#read data from retirement data website: https://www.ssa.gov/oact/progdata/nra.html
retirement_df=pd.read_html('https://www.ssa.gov/oact/progdata/nra.html')
retirement_df
# Out:
# [                                        Year of birth  \
#  0                                      1937 and prior
#  1                                                1938
#  2                                                1939
#  3                                                1940
#  4                                                1941
#  5                                                1942
#  6                                             1943-54
#  7                                                1955
#  8                                                1956
#  9                                                1957
#  10                                               1958
#  11                                               1959
#  12                                     1960 and later
#  13  Notes: 1. Persons born on January 1 of any yea...
#
#                                                    Age
#  0                                                  65
# ...

# %%
#write dataframe into csv
employee_df = pd.DataFrame({'Employee ID':[1, 2, 3, 4], 
                            'Employee Name':['Laila Aly', 'Kate Steve', 'Nicole Mitch', 'Francis Morris'], 
                            'Annual Salary [$]':[35000, 40000, 100000, 25000], 
                            'Years with Company':[5, 7, 10, 1]})
employee_df
# Out:
#    Employee ID   Employee Name  Annual Salary [$]  Years with Company
# 0            1       Laila Aly              35000                   5
# 1            2      Kate Steve              40000                   7
# 2            3    Nicole Mitch             100000                  10
# 3            4  Francis Morris              25000                   1

# %%
#write dataframe into csv with a index
employee_df.to_csv = ('employee_info_with_index.csv', index = True)
employee_df.to_csv
# Out:
#   File "<ipython-input-6-0e181117cdc7>", line 2
#     employee_df.to_csv = ('employee_info_with_index.csv', index = True)
#                                                                 ^
# SyntaxError: invalid syntax

# %%
#write dataframe into csv without index
employee_df.to_csv = ('employee_info_without_index.csv', index = False)
employee_df.to_csv
# Out:
#   File "<ipython-input-7-e60f7c00bc61>", line 2
#     employee_df.to_csv = ('employee_info_without_index.csv', index = False)
#                                                                    ^
# SyntaxError: invalid syntax

# %%
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#make column name the index
employee_df.set_index("First Name", inplace=True)
employee_df
# Out:
#            Last Name     Salary  Years with Company Postal Code  \
# First Name
# Mike             Moe    5000.00                   3     N94 3M0
# Noah            Ryan   10000.00                   8     N8S 14K
# Nina          Keller    9072.02                  17     S1T 4E6
# Chanel         Steve   11072.02                  12     N7T 3E6
# Kate            Noor    5000.00                  23     K8N 5H6
# Samer             Mo  100000.00                  13     J7H 3HY
# Heba          Ismail   50000.00                   7     K8Y 3M8
# Laila            Aly   20000.00                   5     J8Y 3M0
# Joseph        Patton    2629.13                   2     M6U 5U7
# Noah           Moran    8626.96                  11     K2D 4M9
#
#                               Email
# First Name
# Mike                 bird@gmail.com
# Noah             nsmall@hotmail.com
# Nina                azikez@gahew.mr
# Chanel             chanel@gmail.com
# Kate               kate@hotmail.com
# ...

# %%
#reset index
employee_df.reset_index(inplace=True)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#can change index from reading csv
employee_df= pd.read_csv('employee_information.csv', index_col='First Name')
employee_df
# Out:
#            Last Name     Salary  Years with Company Postal Code  \
# First Name
# Mike             Moe    5000.00                   3     N94 3M0
# Noah            Ryan   10000.00                   8     N8S 14K
# Nina          Keller    9072.02                  17     S1T 4E6
# Chanel         Steve   11072.02                  12     N7T 3E6
# Kate            Noor    5000.00                  23     K8N 5H6
# Samer             Mo  100000.00                  13     J7H 3HY
# Heba          Ismail   50000.00                   7     K8Y 3M8
# Laila            Aly   20000.00                   5     J8Y 3M0
# Joseph        Patton    2629.13                   2     M6U 5U7
# Noah           Moran    8626.96                  11     K2D 4M9
#
#                               Email
# First Name
# Mike                 bird@gmail.com
# Noah             nsmall@hotmail.com
# Nina                azikez@gahew.mr
# Chanel             chanel@gmail.com
# Kate               kate@hotmail.com
# ...

# %%
# Last name as index
employee_df.set_index("Last Name", inplace=True)
employee_df
# Out:
#               Salary  Years with Company Postal Code                    Email
# Last Name
# Moe          5000.00                   3     N94 3M0           bird@gmail.com
# Ryan        10000.00                   8     N8S 14K       nsmall@hotmail.com
# Keller       9072.02                  17     S1T 4E6          azikez@gahew.mr
# Steve       11072.02                  12     N7T 3E6         chanel@gmail.com
# Noor         5000.00                  23     K8N 5H6         kate@hotmail.com
# Mo         100000.00                  13     J7H 3HY          samer@gmail.com
# Ismail      50000.00                   7     K8Y 3M8  heba.ismail@hotmail.com
# Aly         20000.00                   5     J8Y 3M0      Laila.a@hotmail.com
# Patton       2629.13                   2     M6U 5U7           daafeja@boh.jm
# Moran        8626.96                  11     K2D 4M9        guutodi@bigwoc.kw

# %%
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#grabbing a column from dataframe
sample = employee_df['Email']
sample
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
#confirm data type . only has one column
type(sample)
# Out:
# pandas.core.series.Series

# %%
#or use to grab a column
employee_df.Email
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
#for column with spaces use bracket
employee_df['Years with Company']
# Out:
# 0     3
# 1     8
# 2    17
# 3    12
# 4    23
# 5    13
# 6     7
# 7     5
# 8     2
# 9    11
# Name: Years with Company, dtype: int64

# %%
#grab multiple columns
sample= employee_df[['First Name', 'Salary']]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
#type dataframe has mulitple column and rich formatting
type(sample)
# Out:
# pandas.core.frame.DataFrame

# %%
my_columns=['First Name', 'Salary']
sample=employee_df[my_columns]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
#in order to access row means grab at index 0 but not include 2
employee_df[0:2]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 0       Mike       Moe   5000.0                   3     N94 3M0
# 1       Noah      Ryan  10000.0                   8     N8S 14K
#
#                 Email
# 0      bird@gmail.com
# 1  nsmall@hotmail.com

# %%
my_columns=['First Name', 'Years with Company','Salary']
sample=employee_df[my_columns]
sample
# Out:
#   First Name  Years with Company     Salary
# 0       Mike                   3    5000.00
# 1       Noah                   8   10000.00
# 2       Nina                  17    9072.02
# 3    Chanel                   12   11072.02
# 4       Kate                  23    5000.00
# 5      Samer                  13  100000.00
# 6       Heba                   7   50000.00
# 7      Laila                   5   20000.00
# 8     Joseph                   2    2629.13
# 9       Noah                  11    8626.96

# %%
#add or delete columns in dataframes
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#add colunm
employee_df['Age']=[24,34,38,56,46,21,18,45,43,37]
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email  Age
# 0           bird@gmail.com   24
# 1       nsmall@hotmail.com   34
# 2          azikez@gahew.mr   38
# 3         chanel@gmail.com   56
# 4         kate@hotmail.com   46
# 5          samer@gmail.com   21
# ...

# %%
#insert a new column into certain position 0
employee_df.insert(0,column ='Credit Score', value=[600,567,700,809,467,591,753,608,890,786])
employee_df
# Out:
#    Credit Score First Name Last Name     Salary  Years with Company  \
# 0           600       Mike       Moe    5000.00                   3
# 1           567       Noah      Ryan   10000.00                   8
# 2           700       Nina    Keller    9072.02                  17
# 3           809    Chanel      Steve   11072.02                  12
# 4           467       Kate      Noor    5000.00                  23
# 5           591      Samer        Mo  100000.00                  13
# 6           753       Heba    Ismail   50000.00                   7
# 7           608      Laila       Aly   20000.00                   5
# 8           890     Joseph    Patton    2629.13                   2
# 9           786       Noah     Moran    8626.96                  11
#
#   Postal Code                    Email  Age
# 0     N94 3M0           bird@gmail.com   24
# 1     N8S 14K       nsmall@hotmail.com   34
# 2     S1T 4E6          azikez@gahew.mr   38
# ...

# %%
#delete a column
del employee_df['Email']
employee_df
# Out:
#    Credit Score First Name Last Name     Salary  Years with Company  \
# 0           600       Mike       Moe    5000.00                   3
# 1           567       Noah      Ryan   10000.00                   8
# 2           700       Nina    Keller    9072.02                  17
# 3           809    Chanel      Steve   11072.02                  12
# 4           467       Kate      Noor    5000.00                  23
# 5           591      Samer        Mo  100000.00                  13
# 6           753       Heba    Ismail   50000.00                   7
# 7           608      Laila       Aly   20000.00                   5
# 8           890     Joseph    Patton    2629.13                   2
# 9           786       Noah     Moran    8626.96                  11
#
#   Postal Code  Age
# 0     N94 3M0   24
# 1     N8S 14K   34
# 2     S1T 4E6   38
# 3     N7T 3E6   56
# 4     K8N 5H6   46
# 5     J7H 3HY   21
# 6     K8Y 3M8   18
# 7     J8Y 3M0   45
# 8     M6U 5U7   43
# ...

# %%
#remove columns . axis 1 means columns not rows., inplace means forcing change in memory permanently
employee_df.drop(labels=['Last Name','Postal Code'], axis = 1, inplace=True)
employee_df
# Out:
#    Credit Score First Name     Salary  Years with Company  Age
# 0           600       Mike    5000.00                   3   24
# 1           567       Noah   10000.00                   8   34
# 2           700       Nina    9072.02                  17   38
# 3           809    Chanel    11072.02                  12   56
# 4           467       Kate    5000.00                  23   46
# 5           591      Samer  100000.00                  13   21
# 6           753       Heba   50000.00                   7   18
# 7           608      Laila   20000.00                   5   45
# 8           890     Joseph    2629.13                   2   43
# 9           786       Noah    8626.96                  11   37

# %%
#remove columns and store somewhere else using pop.  think of pop as extracting column and puts into pandaSeries
years_with_company= employee_df.pop('Years with Company')
years_with_company
# Out:
# 0     3
# 1     8
# 2    17
# 3    12
# 4    23
# 5    13
# 6     7
# 7     5
# 8     2
# 9    11
# Name: Years with Company, dtype: int64

# %%
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
employee_df.insert(0,column ='Has mortgage', value=[1,0,0,0,0,1,1,0,0,1])
employee_df
# Out:
#    Has mortgage First Name Last Name     Salary  Years with Company  \
# 0             1       Mike       Moe    5000.00                   3
# 1             0       Noah      Ryan   10000.00                   8
# 2             0       Nina    Keller    9072.02                  17
# 3             0    Chanel      Steve   11072.02                  12
# 4             0       Kate      Noor    5000.00                  23
# 5             1      Samer        Mo  100000.00                  13
# 6             1       Heba    Ismail   50000.00                   7
# 7             0      Laila       Aly   20000.00                   5
# 8             0     Joseph    Patton    2629.13                   2
# 9             1       Noah     Moran    8626.96                  11
#
#   Postal Code                    Email
# 0     N94 3M0           bird@gmail.com
# 1     N8S 14K       nsmall@hotmail.com
# 2     S1T 4E6          azikez@gahew.mr
# 3     N7T 3E6         chanel@gmail.com
# ...

# %%
# reading a file and indexing Last Name
employee_df = pd.read_csv('employee_information.csv', index_col="Last Name")
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Moe             Mike    5000.00                   3     N94 3M0
# Ryan            Noah   10000.00                   8     N8S 14K
# Keller          Nina    9072.02                  17     S1T 4E6
# Steve        Chanel    11072.02                  12     N7T 3E6
# Noor            Kate    5000.00                  23     K8N 5H6
# Mo             Samer  100000.00                  13     J7H 3HY
# Ismail          Heba   50000.00                   7     K8Y 3M8
# Aly            Laila   20000.00                   5     J8Y 3M0
# Patton        Joseph    2629.13                   2     M6U 5U7
# Moran           Noah    8626.96                  11     K2D 4M9
#
#                              Email
# Last Name
# Moe                 bird@gmail.com
# Ryan            nsmall@hotmail.com
# Keller             azikez@gahew.mr
# Steve             chanel@gmail.com
# Noor              kate@hotmail.com
# ...

# %%
#now you can sort by alphabetical the last name
employee_df.sort_index(inplace=True)
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   20000.00                   5     J8Y 3M0
# Ismail          Heba   50000.00                   7     K8Y 3M8
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
# Moe             Mike    5000.00                   3     N94 3M0
# Moran           Noah    8626.96                  11     K2D 4M9
# Noor            Kate    5000.00                  23     K8N 5H6
# Patton        Joseph    2629.13                   2     M6U 5U7
# Ryan            Noah   10000.00                   8     N8S 14K
# Steve        Chanel    11072.02                  12     N7T 3E6
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com
# Moe                 bird@gmail.com
# ...

# %%
#use loc or label-based selection to filter row or column. whereas iloc is integer-based selection
employee_df.loc['Aly']
# Out:
# First Name                          Laila
# Salary                              20000
# Years with Company                      5
# Postal Code                       J8Y 3M0
# Email                 Laila.a@hotmail.com
# Name: Aly, dtype: object

# %%
#select multiple rows inclusive of Aly and Patton
employee_df.loc['Aly':'Patton']
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   20000.00                   5     J8Y 3M0
# Ismail          Heba   50000.00                   7     K8Y 3M8
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
# Moe             Mike    5000.00                   3     N94 3M0
# Moran           Noah    8626.96                  11     K2D 4M9
# Noor            Kate    5000.00                  23     K8N 5H6
# Patton        Joseph    2629.13                   2     M6U 5U7
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com
# Moe                 bird@gmail.com
# Moran            guutodi@bigwoc.kw
# Noor              kate@hotmail.com
# Patton              daafeja@boh.jm

# %%
#obtain all up to Keller
employee_df.loc[:'Keller']
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila  20000.00                   5     J8Y 3M0
# Ismail          Heba  50000.00                   7     K8Y 3M8
# Keller          Nina   9072.02                  17     S1T 4E6
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Ismail     heba.ismail@hotmail.com
# Keller             azikez@gahew.mr

# %%
#or cherrypick
employee_df.loc[['Mo','Moran','Ismail']]
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Mo             Samer  100000.00                  13     J7H 3HY
# Moran           Noah    8626.96                  11     K2D 4M9
# Ismail          Heba   50000.00                   7     K8Y 3M8
#
#                              Email
# Last Name
# Mo                 samer@gmail.com
# Moran            guutodi@bigwoc.kw
# Ismail     heba.ismail@hotmail.com

# %%
#or random select
employee_df.sample(n=5,axis=0)
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila  20000.00                   5     J8Y 3M0
# Moran           Noah   8626.96                  11     K2D 4M9
# Patton        Joseph   2629.13                   2     M6U 5U7
# Steve        Chanel   11072.02                  12     N7T 3E6
# Keller          Nina   9072.02                  17     S1T 4E6
#
#                          Email
# Last Name
# Aly        Laila.a@hotmail.com
# Moran        guutodi@bigwoc.kw
# Patton          daafeja@boh.jm
# Steve         chanel@gmail.com
# Keller         azikez@gahew.mr

# %%
#or fraction
employee_df.sample(frac=0.3, axis=0)
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Keller          Nina   9072.02                  17     S1T 4E6
# Moran           Noah   8626.96                  11     K2D 4M9
# Ryan            Noah  10000.00                   8     N8S 14K
#
#                         Email
# Last Name
# Keller        azikez@gahew.mr
# Moran       guutodi@bigwoc.kw
# Ryan       nsmall@hotmail.com

# %%
employee_df = pd.read_csv('employee_information.csv', index_col="First Name")
employee_df
# Out:
#            Last Name     Salary  Years with Company Postal Code  \
# First Name
# Mike             Moe    5000.00                   3     N94 3M0
# Noah            Ryan   10000.00                   8     N8S 14K
# Nina          Keller    9072.02                  17     S1T 4E6
# Chanel         Steve   11072.02                  12     N7T 3E6
# Kate            Noor    5000.00                  23     K8N 5H6
# Samer             Mo  100000.00                  13     J7H 3HY
# Heba          Ismail   50000.00                   7     K8Y 3M8
# Laila            Aly   20000.00                   5     J8Y 3M0
# Joseph        Patton    2629.13                   2     M6U 5U7
# Noah           Moran    8626.96                  11     K2D 4M9
#
#                               Email
# First Name
# Mike                 bird@gmail.com
# Noah             nsmall@hotmail.com
# Nina                azikez@gahew.mr
# Chanel             chanel@gmail.com
# Kate               kate@hotmail.com
# ...

# %%
employee_df.sample(n=2,axis=0)
# Out:
#            Last Name    Salary  Years with Company Postal Code  \
# First Name
# Noah            Ryan   10000.0                   8     N8S 14K
# Samer             Mo  100000.0                  13     J7H 3HY
#
#                          Email
# First Name
# Noah        nsmall@hotmail.com
# Samer          samer@gmail.com

# %%
#read file
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#using index to obtain access to row 9
employee_df.iloc[9]
# Out:
# First Name                         Noah
# Last Name                         Moran
# Salary                          8626.96
# Years with Company                   11
# Postal Code                     K2D 4M9
# Email                 guutodi@bigwoc.kw
# Name: 9, dtype: object

# %%
#grab multiple rows from 2 up until 5 but not including 5
employee_df.iloc[2:5]
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 2       Nina    Keller   9072.02                  17     S1T 4E6
# 3    Chanel      Steve  11072.02                  12     N7T 3E6
# 4       Kate      Noor   5000.00                  23     K8N 5H6
#
#               Email
# 2   azikez@gahew.mr
# 3  chanel@gmail.com
# 4  kate@hotmail.com

# %%
#grab all up until 4 but not include 4
employee_df.iloc[0:4]
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 0       Mike       Moe   5000.00                   3     N94 3M0
# 1       Noah      Ryan  10000.00                   8     N8S 14K
# 2       Nina    Keller   9072.02                  17     S1T 4E6
# 3    Chanel      Steve  11072.02                  12     N7T 3E6
#
#                 Email
# 0      bird@gmail.com
# 1  nsmall@hotmail.com
# 2     azikez@gahew.mr
# 3    chanel@gmail.com

# %%
#grab select rows using list of index
employee_df.iloc[[2,4,9]]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 2       Nina    Keller  9072.02                  17     S1T 4E6
# 4       Kate      Noor  5000.00                  23     K8N 5H6
# 9       Noah     Moran  8626.96                  11     K2D 4M9
#
#                Email
# 2    azikez@gahew.mr
# 4   kate@hotmail.com
# 9  guutodi@bigwoc.kw

# %%
#slicing the data. grab row 4, grab colunm 0 but not include 3
employee_df.iloc[4,0:3]
# Out:
# First Name    Kate
# Last Name     Noor
# Salary        5000
# Name: 4, dtype: object

# %%
#grab last 2 rows
employee_df.iloc[-2:]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 8     Joseph    Patton  2629.13                   2     M6U 5U7
# 9       Noah     Moran  8626.96                  11     K2D 4M9
#
#                Email
# 8     daafeja@boh.jm
# 9  guutodi@bigwoc.kw

# %%
#or
employee_df.iloc[8:]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 8     Joseph    Patton  2629.13                   2     M6U 5U7
# 9       Noah     Moran  8626.96                  11     K2D 4M9
#
#                Email
# 8     daafeja@boh.jm
# 9  guutodi@bigwoc.kw

# %%
#increase salaries by 1000 by performing broadcasting function
employee_df['Salary']=employee_df['Salary']+1000
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe   11000.00                   3     N94 3M0
# 1       Noah      Ryan   16000.00                   8     N8S 14K
# 2       Nina    Keller   15072.02                  17     S1T 4E6
# 3    Chanel      Steve   17072.02                  12     N7T 3E6
# 4       Kate      Noor   11000.00                  23     K8N 5H6
# 5      Samer        Mo  106000.00                  13     J7H 3HY
# 6       Heba    Ismail   56000.00                   7     K8Y 3M8
# 7      Laila       Aly   26000.00                   5     J8Y 3M0
# 8     Joseph    Patton    8629.13                   2     M6U 5U7
# 9       Noah     Moran   14626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#alternatively
employee_df['Salary']=employee_df['Salary'].add(1000)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe   12000.00                   3     N94 3M0
# 1       Noah      Ryan   17000.00                   8     N8S 14K
# 2       Nina    Keller   16072.02                  17     S1T 4E6
# 3    Chanel      Steve   18072.02                  12     N7T 3E6
# 4       Kate      Noor   12000.00                  23     K8N 5H6
# 5      Samer        Mo  107000.00                  13     J7H 3HY
# 6       Heba    Ismail   57000.00                   7     K8Y 3M8
# 7      Laila       Aly   27000.00                   5     J8Y 3M0
# 8     Joseph    Patton    9629.13                   2     M6U 5U7
# 9       Noah     Moran   15626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#to convert cad to usd
employee_df['Salary (CAD)']=employee_df['Salary'].mul(1.3)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe   12000.00                   3     N94 3M0
# 1       Noah      Ryan   17000.00                   8     N8S 14K
# 2       Nina    Keller   16072.02                  17     S1T 4E6
# 3    Chanel      Steve   18072.02                  12     N7T 3E6
# 4       Kate      Noor   12000.00                  23     K8N 5H6
# 5      Samer        Mo  107000.00                  13     J7H 3HY
# 6       Heba    Ismail   57000.00                   7     K8Y 3M8
# 7      Laila       Aly   27000.00                   5     J8Y 3M0
# 8     Joseph    Patton    9629.13                   2     M6U 5U7
# 9       Noah     Moran   15626.96                  11     K2D 4M9
#
#                      Email  Salary (CAD)
# 0           bird@gmail.com     15600.000
# 1       nsmall@hotmail.com     22100.000
# 2          azikez@gahew.mr     20893.626
# 3         chanel@gmail.com     23493.626
# ...

# %%
#update a email of given customer column 5
employee_df.iloc[4,5]="kate@gmail.com"
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe   12000.00                   3     N94 3M0
# 1       Noah      Ryan   17000.00                   8     N8S 14K
# 2       Nina    Keller   16072.02                  17     S1T 4E6
# 3    Chanel      Steve   18072.02                  12     N7T 3E6
# 4       Kate      Noor   12000.00                  23     K8N 5H6
# 5      Samer        Mo  107000.00                  13     J7H 3HY
# 6       Heba    Ismail   57000.00                   7     K8Y 3M8
# 7      Laila       Aly   27000.00                   5     J8Y 3M0
# 8     Joseph    Patton    9629.13                   2     M6U 5U7
# 9       Noah     Moran   15626.96                  11     K2D 4M9
#
#                      Email  Salary (CAD)
# 0           bird@gmail.com     15600.000
# 1       nsmall@hotmail.com     22100.000
# 2          azikez@gahew.mr     20893.626
# 3         chanel@gmail.com     23493.626
# ...

# %%
# 12% increase in salaries
employee_df['Salary New']=employee_df['Salary'].mul(1.12)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe   12000.00                   3     N94 3M0
# 1       Noah      Ryan   17000.00                   8     N8S 14K
# 2       Nina    Keller   16072.02                  17     S1T 4E6
# 3    Chanel      Steve   18072.02                  12     N7T 3E6
# 4       Kate      Noor   12000.00                  23     K8N 5H6
# 5      Samer        Mo  107000.00                  13     J7H 3HY
# 6       Heba    Ismail   57000.00                   7     K8Y 3M8
# 7      Laila       Aly   27000.00                   5     J8Y 3M0
# 8     Joseph    Patton    9629.13                   2     M6U 5U7
# 9       Noah     Moran   15626.96                  11     K2D 4M9
#
#                      Email  Salary (CAD)  Salary(New)   Salary New
# 0           bird@gmail.com     15600.000   13440.0000   13440.0000
# 1       nsmall@hotmail.com     22100.000   19040.0000   19040.0000
# ...

# %%
#total sum of salary
employee_df['Salary New'].sum()
# Out:
# 326368.1456000001

# %%
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#can sort values with years with company not permananently
employee_df.sort_values(by='Years with Company')
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
#
#                      Email
# 8           daafeja@boh.jm
# 0           bird@gmail.com
# 7      Laila.a@hotmail.com
# 6  heba.ismail@hotmail.com
# 1       nsmall@hotmail.com
# 9        guutodi@bigwoc.kw
# 3         chanel@gmail.com
# ...

# %%
# now you can permanantly sort
employee_df.sort_values(by='Years with Company', inplace=True)

# %%
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
#
#                      Email
# 8           daafeja@boh.jm
# 0           bird@gmail.com
# 7      Laila.a@hotmail.com
# 6  heba.ismail@hotmail.com
# 1       nsmall@hotmail.com
# 9        guutodi@bigwoc.kw
# 3         chanel@gmail.com
# ...

# %%
#set by descending value
employee_df.sort_values(by='Years with Company', ascending=False, inplace=True)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
#
#                      Email
# 4         kate@hotmail.com
# 2          azikez@gahew.mr
# 5          samer@gmail.com
# 3         chanel@gmail.com
# 9        guutodi@bigwoc.kw
# 1       nsmall@hotmail.com
# 6  heba.ismail@hotmail.com
# ...

# %%
#sort by index
employee_df.sort_index()
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba    Ismail   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# ...
